# %% [markdown]
# # Proyecto
#
# # Oscilador Paramétrico

# %%
using PyPlot

# %%
include("TaylorDiff.jl")
using ATaylor

# %% [markdown]
# **Con el método de Taylor**

# %%
#método con dos ecuaciones para las funciones del ejercicio 1, con codicion inicial x0 para f y y0 para g
function coefTaylor(f,g,x0,y0,t0,N)
    t=taylor([t0],N)
    x=taylor([x0],N)
    y=taylor([y0],N)
    for n in 1:N
        q=f(t,x,y)#modificación 
        w=g(t,x,y)#modificación
        a=taylor(q.v,n+1)
        b=taylor(w.v,n+1)
        x.v[n+1]=a.v[n]/n
        y.v[n+1]=b.v[n]/n
    end
    return Taylor(x.v),Taylor(y.v)
end 
function pasointh(x,y,ϵ)
    fh=(ϵ/abs(x.v[end]))^(1/(length(x.v)-1))
    fl=(ϵ/abs(x.v[end-2]))^(1/(length(x.v)-3))
    gh=(ϵ/abs(y.v[end]))^(1/(length(y.v)-1))
    gl=(ϵ/abs(y.v[end-2]))^(1/(length(y.v)-3))
    return min(fh,fl,gh,gl)
end
function solecuacion(f,g,x0,y0,ϵ,N,tf)
    M=300000 #número máximo de elementos para los vectores
    a=zeros(eltype(x0), M)
    da=zeros(eltype(x0), M)
    s1=zeros(eltype(x0), M)
    s2=zeros(eltype(x0), M)
    t=zeros(eltype(x0), M)
    s1[1]=x0
    a[1]=x0
    s2[1]=y0
    da[1]=y0
    i=2
    while i<=M && t[i-1]<=tf
        x,y=coefTaylor(f,g,x0,y0,N)
        h=pasointh(x,y,ϵ)
        x0=Horner(h,x,x.n+1)
        y0=Horner(h,y,y.n+1)
        s1[i]=x0
        s2[i]=y0
        t[i]=t[i-1]+h
        a[i]=(2.0)*cos(t[i]*sqrt(2))
        da[i]=-(2.0)*sqrt(2)*sin(t[i]*sqrt(2))
        i+=1
    end
    t=Taylor(t);s1=Taylor(s1);s2=Taylor(s2);a=Taylor(a);da=Taylor(da)
    return t.v,s1.v,s2.v,a.v,da.v
end
# Out:
# WARNING: Method definition coefTaylor(Any, Any, Any, Any, Any, Any) in module Main at In[28]:3 overwritten at In[43]:3.
# WARNING: Method definition pasointh(Any, Any, Any) in module Main at In[28]:17 overwritten at In[43]:17.
# WARNING: Method definition solecuacion(Any, Any, Any, Any, Any, Any, Any) in module Main at In[28]:24 overwritten at In[43]:24.
# solecuacion (generic function with 1 method)

# %%
f(t,x,y)=y #primera derivada de x
g(t,x,y)=-(α+β*cos(t))*sin(x) #segunda derivada de x
α=1.0
β=1.0
x0=0.0
y0=1.0
N=25
ϵ=1e-34
t0=0.0
tf=300
t,s1,s2,a,da=solecuacion(f,g,x0,y0,ϵ,N,tf)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,s2,",")    # este comando pinta la función f'(x); 
title(L"Gráfica 1. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# WARNING: Method definition f(Any, Any, Any) in module Main at In[45]:1 overwritten at In[46]:1.
# WARNING: Method definition g(Any, Any, Any) in module Main at In[45]:2 overwritten at In[46]:2.
# MethodError: no method matching coefTaylor(::#f, ::#g, ::Float64, ::Float64, ::Int64)
# Closest candidates are:
#   coefTaylor(::Any, ::Any, ::Any, ::Any, ::Any, ::Any) at In[43]:3
#
#  in solecuacion(::Function, ::Function, ::Float64, ::Float64, ::Float64, ::Int64, ::Int64) at ./In[43]:36

# %%
yT=taylor([1,1/1,2],1)
#xT=Taylor([x0],0)

# %%
α=1.0
β=100.0
x0=0.0
y0=1.0
N=25
ϵ=1e-34
tf=300
t,s1A,s2A,a,da=solecuacion(f,g,x0,y0,ϵ,N,tf)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
#x = linspace(0.8, 6.2, 100)
plot(s1,s2,",")    # este comando pinta la función f'(x); 
title(L"Gráfica 1. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()

# %%
function coefTaylor(f,g,x0,y0,t0,N)
    t=taylor([t0],N)
    x=taylor([x0],N)
    y=taylor([y0],N)
    for n in 1:N
        q=f(t,x,y)#modificación 
        w=g(t,x,y)#modificación
        a=taylor(q.v,n+1)
        b=taylor(w.v,n+1)
        x.v[n+1]=a.v[n]/n
        y.v[n+1]=b.v[n]/n
    end
    return Taylor(x.v),Taylor(y.v)
end

# %%
eq1(t,x,y)=y #primera derivada de x
eq2(t,x,y)=-(α+β*cos(t))*sin(x) #segunda derivada de x
α=1.0
β=1.0
x0=0.0
t0=0.0
y0=1.0
N=25
coefTaylor(f,g,x0,y0,t0,N)

# %%
using Distributions

# %%
###################
##  Create Data  ##
###################
n = 100
x = linspace(-3, 3, n)
y = linspace(-3,3,n)

xgrid = repmat(x',n,1)
ygrid = repmat(y,1,n)

z = zeros(n,n)

for i in 1:n
    for j in 1:n
        z[i:i,j:j] = pdf(MvNormal(eye(2)),[x[i];y[j]])
    end
end

# %%
############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(10,10))
ax = fig[:add_subplot](2,1,1, projection = "3d")
ax[:plot_surface](xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("plasma"), alpha=0.8, linewidth=0.25)
xlabel("Eje X")
ylabel("Eje Y")
title("Gráfica de la superficie")
#=
subplot(212)
ax = fig[:add_subplot](2,1,2)
cp = ax[:contour](xgrid, ygrid, z, colors="black", linewidth=2.0)
ax[:clabel](cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
title("Contour Plot")
tight_layout()=#
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fd4d4fb1cd0>)
# PyObject <matplotlib.text.Text object at 0x7fd4d53bd2d0>

# %%
pdf(MvNormal(eye(2)),[1;1])
# Out:
# 0.05854983152431917

# %%
α β
# Out:
# search: pdf logpdf logpdf! gradlogpdf Cptrdiff_t isposdef isposdef!
# No documentation found.
#
# `Distributions.pdf` is a `Function`.
#
# ```
# # 76 methods for generic function "pdf":
# pdf(d::Distributions.DiscreteUniform) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/discreteuniform.jl:79
# pdf(d::Distributions.DiscreteUniform, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/discreteuniform.jl:75
# pdf(d::Distributions.Hypergeometric, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Kolmogorov, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/kolmogorov.jl:74
# pdf(d::Distributions.EmpiricalUnivariateDistribution, x::Float64) at /home/madara/.julia/v0.5/Distributions/src/empirical.jl:57
# pdf(d::Distributions.Bernoulli) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/bernoulli.jl:85
# pdf(d::Distributions.Bernoulli, x::Bool) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/bernoulli.jl:81
# pdf(d::Distributions.Bernoulli, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/bernoulli.jl:82
# pdf(d::Distributions.BetaBinomial) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/betabinomial.jl:92
# pdf(d::Distributions.BetaBinomial, k::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/betabinomial.jl:84
# pdf(d::Distributions.Binomial, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Categorical) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/categorical.jl:168
# pdf{T<:Real}(d::Distributions.Categorical{T}, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/categorical.jl:164
# pdf{T<:Real}(d::Distributions.Geometric{T}, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/geometric.jl:70
# pdf(d::Distributions.NegativeBinomial, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.FisherNoncentralHypergeometric, k::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/noncentralhypergeometric.jl:89
# pdf(d::Distributions.WalleniusNoncentralHypergeometric, k::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/noncentralhypergeometric.jl:133
# pdf(d::Distributions.Poisson, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Skellam, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/skellam.jl:69
# pdf(d::Distributions.PoissonBinomial) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/poissonbinomial.jl:113
# pdf(d::Distributions.PoissonBinomial, k::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariate/discrete/poissonbinomial.jl:109
# pdf(d::Distributions.Arcsine, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/arcsine.jl:74
# pdf(d::Distributions.Beta, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.BetaPrime, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/betaprime.jl:92
# pdf{T<:Real}(d::Distributions.Biweight{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/biweight.jl:31
# pdf(d::Distributions.Cauchy, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/cauchy.jl:77
# pdf(d::Distributions.Chisq, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Chi, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/chi.jl:76
# pdf{T<:Real}(d::Distributions.Cosine{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/cosine.jl:56
# pdf{T<:Real}(d::Distributions.Epanechnikov{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/epanechnikov.jl:43
# pdf(d::Distributions.Exponential, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/exponential.jl:66
# pdf(d::Distributions.FDist, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Frechet, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/frechet.jl:121
# pdf(d::Distributions.Gamma, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Erlang, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.GeneralizedPareto, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/generalizedpareto.jl:136
# pdf{T<:Real}(d::Distributions.GeneralizedExtremeValue{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/generalizedextremevalue.jl:199
# pdf(d::Distributions.Gumbel, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/gumbel.jl:76
# pdf(d::Distributions.InverseGamma, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/inversegamma.jl:88
# pdf{T<:Real}(d::Distributions.InverseGaussian{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/inversegaussian.jl:78
# pdf(d::Distributions.Laplace, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/laplace.jl:77
# pdf(d::Distributions.Levy, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/levy.jl:66
# pdf(d::Distributions.Logistic, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/logistic.jl:76
# pdf(d::Distributions.NoncentralBeta, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.NoncentralChisq, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.NoncentralF, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.NoncentralT, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.Normal, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf(d::Distributions.NormalCanon, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/normalcanon.jl:55
# pdf(d::Distributions.NormalInverseGaussian, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/normalinversegaussian.jl:52
# pdf(d::Distributions.LogNormal, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/lognormal.jl:89
# pdf{T<:Real}(d::Distributions.Pareto{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/pareto.jl:83
# pdf{T<:Real}(d::Distributions.Rayleigh{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/rayleigh.jl:66
# pdf{T<:Real}(d::Distributions.SymTriangularDist{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/symtriangular.jl:73
# pdf(d::Distributions.TDist, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:320
# pdf{T<:Real}(d::Distributions.TriangularDist{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/triangular.jl:96
# pdf{T<:Real}(d::Distributions.Triweight{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/triweight.jl:40
# pdf{T<:Real}(d::Distributions.Uniform{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/uniform.jl:68
# pdf(d::Distributions.VonMises, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/vonmises.jl:66
# pdf{T<:Real}(d::Distributions.Weibull{T}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariate/continuous/weibull.jl:92
# pdf(d::Distributions.EdgeworthZ, x::Float64) at /home/madara/.julia/v0.5/Distributions/src/edgeworth.jl:28
# pdf(d::Distributions.EdgeworthAbstract, x::Float64) at /home/madara/.julia/v0.5/Distributions/src/edgeworth.jl:107
# pdf(d::Distributions.Truncated, x::Float64) at /home/madara/.julia/v0.5/Distributions/src/truncate.jl:40
# pdf(d::Distributions.Truncated, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/truncate.jl:63
# pdf(d::Distributions.AbstractMixtureModel{Distributions.Univariate,Distributions.Continuous,C<:Distributions.Distribution}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/mixtures/mixturemodel.jl:309
# pdf(d::Distributions.AbstractMixtureModel{Distributions.Univariate,Distributions.Discrete,C<:Distributions.Distribution}, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/mixtures/mixturemodel.jl:310
# pdf(d::Distributions.Distribution{Distributions.Univariate,Distributions.Discrete}) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:280
# pdf(d::Distributions.Distribution{Distributions.Univariate,Distributions.Discrete}, x::Int64) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:98
# pdf(d::Distributions.Distribution{Distributions.Univariate,Distributions.Discrete}, x::Integer) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:99
# pdf(d::Distributions.Distribution{Distributions.Univariate,Distributions.Discrete}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:100
# pdf(d::Distributions.Distribution{Distributions.Univariate,Distributions.Continuous}, x::Real) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:102
# pdf(d::Distributions.Distribution{Distributions.Univariate,S<:Distributions.ValueSupport}, X::AbstractArray) at /home/madara/.julia/v0.5/Distributions/src/univariates.jl:205
# pdf(d::Distributions.Distribution{Distributions.Multivariate,S<:Distributions.ValueSupport}, X::AbstractArray{T<:Any,1}) at /home/madara/.julia/v0.5/Distributions/src/multivariates.jl:69
# pdf(d::Distributions.Distribution{Distributions.Multivariate,S<:Distributions.ValueSupport}, X::AbstractArray{T<:Any,2}) at /home/madara/.julia/v0.5/Distributions/src/multivariates.jl:108
# pdf{T<:Real}(d::Distributions.Distribution{Distributions.Matrixvariate,S<:Distributions.ValueSupport}, x::AbstractArray{T,2}) at /home/madara/.julia/v0.5/Distributions/src/matrixvariates.jl:20
# pdf{M<:Array{T,2}}(d::Distributions.Distribution{Distributions.Matrixvariate,S<:Distributions.ValueSupport}, X::AbstractArray{M,N<:Any}) at /home/madara/.julia/v0.5/Distributions/src/matrixvariates.jl:57
# ```
