# %%
using PyPlot
include("Taylor.jl")
using ADT
using ODE

# %%
function ec1(t, x̄)
    
    dx = x̄[2]
    dy = (α + β * cos(t)) * sin(x̄[1])
    
    return [dx; dy]
end
# Out:
# ec1 (generic function with 1 method)

# %%
x̄ = [1.0, 0.0]
t0 = 0.0
tf = 50 * pi

α = 0.0
β = 1.0

t = linspace(t0, tf, 1000)
# Out:
# 1000-element LinSpace{Float64}:
#  0.0,0.157237,0.314474,0.471711,0.628947,…,156.608,156.765,156.922,157.08

# %%
(t1, sol1) = ode45(ec1, x̄, t);

# %%
x1 = map(y -> y[1], sol1)
y1 = map(y -> y[2], sol1);

# %%
plot(x1, y1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc0b5e6c5f8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc0b57a1048>

# %%
(t2, sol2) = integradorT2(ec1, t0, tf, x̄, 10000, 1e-50);
# Out:
# Integracion terminada
# #T = 7679, #X̄ = 7679, n = 7679 / 10000

# %%
x2 = map(y -> y[1], sol2)
y2 = map(y -> y[2], sol2);

# %%
plot(x2, y2)
# xlim(-0.8, -0.7)
# ylim(-0.25, 0.25)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc0b573c860>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc0b572bac8>
