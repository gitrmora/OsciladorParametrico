# %%
using PyPlot
include("Taylor.jl")
using ADT
using ODE

# %%
function ec1(t, x̄)
    
    dx = x̄[2]
    dy = (α + β * cos(t)) * sin(x̄[1])
    
    return [dx; dy]
end
# Out:
# ec1 (generic function with 1 method)

# %%
x̄ = [0.0, 1.0]
t0 = 0.0
tf = 100 * pi

α = -1.0
β = -1.0

t = linspace(t0, tf, 1000)
# Out:
# 1000-element LinSpace{Float64}:
#  0.0,0.314474,0.628947,0.943421,1.25789,…,313.216,313.53,313.845,314.159

# %%
(t1, sol1) = ode45(ec1, x̄, t);

# %%
x1 = map(y -> y[1], sol1)
y1 = map(y -> y[2], sol1);

# %%
plot(x1, y1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa2f3648ac8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa2f1027b70>

# %%
(t2, sol2) = integradorT2(ec1, t0, tf, x̄, 1e-50);

# %%
x2 = map(y -> y[1], sol2)
y2 = map(y -> y[2], sol2);

# %%
plot(x2, y2)
# xlim(-0.75, -0.5)
# ylim(-0.25, 0.25)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa2f1089d30>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fa2f0f41e80>
