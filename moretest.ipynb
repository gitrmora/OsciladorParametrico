# %% [markdown]
# # Oscilador Paramétrico

# %% [markdown]
# Serie de Taylor
# $$f(x)=f(a)+f^{(1)}(a)(x-a)+\frac{f^{(2)}(a)}{2!}(x-a)^2+\cdots +\frac{f^{(n)}(a)}{n!}(x-a)^n+\cdots$$

# %% [markdown]
# Tenemos que resolver la ecuación
# $$\ddot{x}=\left(\alpha+\beta\cos t\right)\sin x$$

# %% [markdown]
# ## Solución del péndulo simple
#
# Un péndulo simple tiene por ecuación
# $$\ddot{x}=-A\sin x$$
#
# Tenemos el siguiente sistema
# $$\begin{array}{l}
# \dot{x}=y\\
# \dot{y}=-A\sin x
# \end{array}$$

# %%
include("TaylorDiff2.jl")
using AT

# %%
using PyPlot

# %%
α=-0.01
β=0
eq1(t,x,y)=y #primera derivada de x
eq2(t,x,y)=(α+β*cos(t))*sin(x) #segunda derivada de x
# Out:
# eq2 (generic function with 1 method)

# %%
t0=0.0
x0=2.0
y0=0.0
N=25
ϵ=1e-34
tf=100
t,x,y=integrador(eq1,eq2,x0,y0,t0,tf,ϵ,N)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,x)    # este comando pinta la función f'(x); 
plot(t,y)
#plot(x,y,",")
title(L"Gráfica. Solución $x(t)$(azúl) y $\dot{x}(t)$(naranja) contra $t$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $t$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20f73f1490>)

# %%
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(x,y,",")    # este comando pinta la función f'(x); 
title(L"Gráfica. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d99d6d50>)

# %% [markdown]
# ## Solución del oscilador armónico
#
# $$\ddot{x}=-2x$$

# %%
α=-2.0
β=0.0
f(t,x,y)=y #primera derivada de x
g(t,x,y)=(α+β*cos(t))*x #segunda derivada de x
# Out:
# g (generic function with 1 method)

# %%
t0=0.0
x0=2.0
y0=0.0
N=25
ϵ=1e-34
tf=100
t,x,y=integrador(f,g,x0,y0,t0,tf,ϵ,N)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,x)    # este comando pinta la función f'(x); 
plot(t,y)
#plot(x,y,",")
title(L"Gráfica. Solución $x(t)$(azúl) y $\dot{x}(t)$(naranja) contra $t$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $t$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d9cb7510>)

# %%
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(x,y,",")    # este comando pinta la función f'(x); 
title(L"Gráfica 12. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d9d48950>)

# %% [markdown]
# # Solución del oscilador paramétrico
#
# $$\ddot{x}=\left(\alpha+\beta\cos t\right)\sin x$$
# Tenemos el siguiente sistema
# $$\begin{array}{l}
# \dot{x}=y\\
# \dot{y}=\left(\alpha+\beta\cos t\right)\sin x
# \end{array}$$

# %%
α=1.0
β=1.0
f1(t,x,y)=y #primera derivada de x
g1(t,x,y)=(α+β*cos(t))*sin(x) #segunda derivada de x
t0=0.0
x0=2.0
y0=0.0
N=25
ϵ=1e-34
tf=500
t,x,y=integrador(f1,g1,x0,y0,t0,tf,ϵ,N)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,x)    # este comando pinta la función f'(x); 
plot(t,y)
#plot(x,y,",")
title(L"Gráfica. Solución $x(t)$(azúl) y $\dot{x}(t)$(naranja) contra $t$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $t$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d9aa7d10>)
# WARNING: Method definition f1(Any, Any, Any) in module Main at In[14]:3 overwritten at In[21]:3.
# WARNING: Method definition g1(Any, Any, Any) in module Main at In[14]:4 overwritten at In[21]:4.

# %%
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(x,y)    # este comando pinta la función f'(x); 
title(L"Gráfica 12. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d99d6190>)

# %%
α=-2.5
β=10.0
f1(t,x,y)=y #primera derivada de x
g1(t,x,y)=(α+β*cos(t))*sin(x) #segunda derivada de x
t0=0.0
x0=2.0
y0=0.0
N=25
ϵ=1e-34
tf=500
t,x,y=integrador(f1,g1,x0,y0,t0,tf,ϵ,N)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,x)    # este comando pinta la función f'(x); 
plot(t,y)
#plot(x,y,",")
title(L"Gráfica. Solución $x(t)$(azúl) y $\dot{x}(t)$(naranja) contra $t$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $t$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d9d718d0>)
# WARNING: Method definition f1(Any, Any, Any) in module Main at In[28]:3 overwritten at In[30]:3.
# WARNING: Method definition g1(Any, Any, Any) in module Main at In[28]:4 overwritten at In[30]:4.

# %%
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(x,y)    # este comando pinta la función f'(x); 
title(L"Gráfica. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f20d9ad6ed0>)

# %% [markdown]
# ** Implementación para $α = 1.0$, $β = 0.0$, $t_0 = 0.0$, $t_f = 50 * \pi$, $x_0=1.0$ y $y_0=0.0$**

# %%
α = 1.0
β = 0.0 #Si beta es cero nos encontramos con el caso del oscilador armónico
f1(t,x,y)=y #primera derivada de x
g1(t,x,y)=(α+β*cos(t))*sin(x) #segunda derivada de x
t0 = 0.0
tf = 50 * pi
x0=1.0
y0=0.0
N=25
ϵ=1e-34
t,x,y=integrador(f1,g1,x0,y0,t0,tf,ϵ,N)
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(t,x)    # este comando pinta la función f'(x); 
plot(t,y)
#plot(x,y,",")
title(L"Gráfica. Solución $x(t)$(azúl) y $\dot{x}(t)$(naranja) contra $t$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $t$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fed889b8990>)

# %%
figure(figsize=(6,4)) # este comando define el tamaño de la figura
plot(x,y)    # este comando pinta la función f'(x); 
title(L"Gráfica. Espacio fase $\dot{x}(t)$ contra $x(t)$", fontsize=10)
xlabel(L"valores de $x$")
ylabel(L"valores de $\dot{x}$")
grid()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fed883c9050>)

# %% [markdown]
# ## Comandos para gráficar en 3D

# %%
using Distributions

# %%
###################
##  Create Data  ##
###################
n = 100
x = linspace(-3, 3, n)
y = linspace(-3,3,n)

xgrid = repmat(x',n,1)
ygrid = repmat(y,1,n)

z = zeros(n,n)

for i in 1:n
    for j in 1:n
        z[i:i,j:j] = pdf(MvNormal(eye(2)),[x[i];y[j]])
    end
end

# %%
############
##  Plot  ##
############
fig = figure("pyplot_surfaceplot",figsize=(10,10))
ax = fig[:add_subplot](2,1,1, projection = "3d")
ax[:plot_surface](xgrid, ygrid, z, rstride=2,edgecolors="k", cstride=2, cmap=ColorMap("plasma"), alpha=0.8, linewidth=0.25)
xlabel("Eje X")
ylabel("Eje Y")
title("Gráfica de la superficie")
#=
subplot(212)
ax = fig[:add_subplot](2,1,2)
cp = ax[:contour](xgrid, ygrid, z, colors="black", linewidth=2.0)
ax[:clabel](cp, inline=1, fontsize=10)
xlabel("X")
ylabel("Y")
title("Contour Plot")
tight_layout()=#
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f227b456e10>)
# PyObject <matplotlib.text.Text object at 0x7f226ffa6ac8>

# %%
pdf(MvNormal(eye(2)),[1;1])
# Out:
# 0.05854983152431917

# %%
α β
# Out:
# syntax: extra token "β" after end of expression

# %%
workspace()
type Taylor{T<:Number}
    v::Array{T,1}
    n::Int
    function Taylor{T}(v::Array{T},n::Int)
        i=length(v)#número de elementos del vector v
        while(v[i]==0&& i>1)
            i=i-1
        end
        if i<n
            x=append!(v,zeros(eltype(v),n+1-length(v)))
            return new(x,i-1)
        elseif i>n
            x=zeros(eltype(v),n+1)
            for i in 1:n+1
                x[i]=v[i]
            end
            return new(x,i-1)
        else
            return new(v,i-1)
        end
    end
end
